# %% [markdown]
# <a href="https://colab.research.google.com/github/hivewire/finetuning-phi-2-text-summarization/blob/main/Task_3_%E2%80%93_Fine_Tuning_Decoder_Only_LLM_(Phi_2)_for_Abstractive_Summarization_(XSum).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 3 – Fine-Tuning Decoder-Only LLM (Phi-2) for Abstractive Summarization (XSum)
# **Tujuan Task**
#
# Pada task ini dilakukan fine-tuning model decoder-only LLM (Phi-2) untuk menghasilkan ringkasan abstraktif singkat dari artikel berita menggunakan dataset XSum.
#
# Karakteristik utama task:
#
# **- Instruction-style prompting**
#
# **- Causal Language Modeling**
#
# **- Abstractive summarization (bukan ekstraktif)**
#
# **- Generation control (max length, temperature, dll.)**

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
import torch
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments
)

# %% [markdown]
# # - Load Dataset
# Tahap ini berfungsi untuk memuat dataset XSum dari file Parquet yang telah diekspor secara resmi. Pendekatan ini dipilih untuk menghindari penggunaan dataset script yang tidak lagi didukung oleh versi terbaru library HuggingFace datasets. Dataset yang dimuat berisi artikel berita dan ringkasan singkat yang sangat abstraktif, yang akan digunakan sebagai data pelatihan dan evaluasi model.

# %%
from datasets import load_dataset

data_files = {
    "train": "/content/sample_data/train-00000-of-00001.parquet",
    "validation": "/content/sample_data/validation-00000-of-00001.parquet",
    "test": "/content/sample_data/test-00000-of-00001.parquet",
}

ds = load_dataset("parquet", data_files=data_files)
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 204045
#     })
#     validation: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 11332
#     })
#     test: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 11334
#     })
# })

# %% [markdown]
# # - Instruction-Style Prompt Formatting
# Tahap ini melakukan transformasi data mentah menjadi format prompt berbasis instruksi. Setiap artikel berita digabungkan dengan instruksi eksplisit untuk melakukan peringkasan dan diikuti oleh ringkasan referensi. Format ini disesuaikan dengan karakteristik model Phi-2 yang merupakan decoder-only language model, sehingga tugas peringkasan dapat diperlakukan sebagai proses generasi teks berbasis instruksi.

# %%
def build_prompt(example):
    prompt = (
        "### Instruction:\n"
        "Summarize the following article in one concise sentence.\n\n"
        "### Article:\n"
        f"{example['document']}\n\n"
        "### Summary:\n"
        f"{example['summary']}"
    )
    return {"text": prompt}

ds = ds.map(
    build_prompt,
    remove_columns=ds["train"].column_names
)

# %% [markdown]
# # - Tokenizer Initialization
# Tahap ini menginisialisasi tokenizer yang sesuai dengan model Phi-2. Tokenizer bertugas mengonversi teks menjadi representasi token numerik yang dapat diproses oleh model. Pada tahap ini juga ditentukan mekanisme padding agar seluruh input memiliki panjang yang seragam saat diproses dalam batch.

# %%
model_name = "microsoft/phi-2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# # - Tokenization
# Tahap ini mengubah prompt berbasis teks menjadi urutan token numerik beserta attention mask. Proses tokenisasi memastikan bahwa setiap input memiliki panjang maksimum yang konsisten dan siap digunakan dalam proses pelatihan. Attention mask digunakan untuk memberi tahu model bagian mana dari input yang perlu diperhatikan.

# %%
def tokenize(batch):
    return tokenizer(
        batch["text"],
        truncation=True,
        padding="max_length",
        max_length=128
    )

tokenized_dataset = ds.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/11332 [00:00<?, ? examples/s]

# %% [markdown]
# # - Label Assignment for Causal Language Modeling
# Tahap ini menambahkan label pelatihan yang disamakan dengan input token. Hal ini diperlukan karena Phi-2 menggunakan pendekatan causal language modeling, di mana model dilatih untuk memprediksi token berikutnya berdasarkan token sebelumnya. Dengan adanya label ini, model dapat menghitung nilai loss dan melakukan proses pembaruan bobot selama pelatihan.

# %%
def add_labels(batch):
    batch["labels"] = batch["input_ids"].copy()
    return batch

tokenized_dataset = tokenized_dataset.map(add_labels, batched=True)
# Out:
# Map:   0%|          | 0/11332 [00:00<?, ? examples/s]

# %% [markdown]
# # - Dataset Subsampling
# Tahap ini membuat subset dari data pelatihan dengan mengambil sebagian kecil sampel dari dataset asli. Langkah ini dilakukan untuk menyesuaikan keterbatasan sumber daya komputasi, khususnya penggunaan GPU T4, serta untuk mempercepat proses fine-tuning tanpa mengubah alur metodologi secara keseluruhan.

# %%
train_subset = (
    tokenized_dataset["train"]
    .shuffle(seed=42)
    .select(range(200))
)

# %% [markdown]
# # - Model Initialization
# Tahap ini memuat model Phi-2 yang telah dilatih sebelumnya dan menyiapkannya untuk proses fine-tuning. Model dikonfigurasikan agar menggunakan presisi FP16 untuk mengurangi penggunaan memori GPU dan meningkatkan efisiensi komputasi selama pelatihan.

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)

for param in model.parameters():
    param.requires_grad = False

for param in model.lm_head.parameters():
    param.requires_grad = True
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
training_args = TrainingArguments(
    output_dir="./outputs/phi2-xsum",

    per_device_train_batch_size=1,
    gradient_accumulation_steps=1,
    num_train_epochs=1,
    learning_rate=5e-4,

    logging_strategy="steps",
    logging_steps=1,

    save_strategy="no",

    fp16=False,
    dataloader_pin_memory=False,
    disable_tqdm=True,

    report_to="none"
)

# %% [markdown]
# # - Fine-Tuning with Trainer
# Tahap ini menjalankan proses fine-tuning dengan menghubungkan model, dataset, dan parameter pelatihan melalui HuggingFace Trainer. Selama proses ini, model secara bertahap menyesuaikan bobotnya untuk menghasilkan ringkasan yang lebih ringkas dan abstraktif sesuai dengan instruksi. Keberhasilan pelatihan ditandai dengan penurunan nilai loss dan tersimpannya checkpoint model yang dapat digunakan untuk inferensi.

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_subset,
)

trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 2.9219, 'grad_norm': 5.4921875, 'learning_rate': 0.0005, 'epoch': 0.005}
# {'loss': 2.9353, 'grad_norm': 5.18359375, 'learning_rate': 0.0004975, 'epoch': 0.01}
# {'loss': 14680.3369, 'grad_norm': 30.40625, 'learning_rate': 0.000495, 'epoch': 0.015}
# {'loss': 18371.4766, 'grad_norm': 14.296875, 'learning_rate': 0.0004925, 'epoch': 0.02}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00049, 'epoch': 0.025}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004875, 'epoch': 0.03}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00048499999999999997, 'epoch': 0.035}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004825, 'epoch': 0.04}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00048, 'epoch': 0.045}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004775, 'epoch': 0.05}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000475, 'epoch': 0.055}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004725, 'epoch': 0.06}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00047, 'epoch': 0.065}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00046750000000000003, 'epoch': 0.07}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000465, 'epoch': 0.075}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004625, 'epoch': 0.08}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00046, 'epoch': 0.085}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004575, 'epoch': 0.09}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000455, 'epoch': 0.095}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00045250000000000005, 'epoch': 0.1}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00045000000000000004, 'epoch': 0.105}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00044750000000000004, 'epoch': 0.11}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00044500000000000003, 'epoch': 0.115}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004425, 'epoch': 0.12}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00044, 'epoch': 0.125}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004375, 'epoch': 0.13}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000435, 'epoch': 0.135}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004325, 'epoch': 0.14}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00043, 'epoch': 0.145}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004275, 'epoch': 0.15}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000425, 'epoch': 0.155}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00042249999999999997, 'epoch': 0.16}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00042, 'epoch': 0.165}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004175, 'epoch': 0.17}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000415, 'epoch': 0.175}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004125, 'epoch': 0.18}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00041, 'epoch': 0.185}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004075, 'epoch': 0.19}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00040500000000000003, 'epoch': 0.195}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004025, 'epoch': 0.2}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0004, 'epoch': 0.205}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003975, 'epoch': 0.21}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000395, 'epoch': 0.215}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003925, 'epoch': 0.22}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00039000000000000005, 'epoch': 0.225}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00038750000000000004, 'epoch': 0.23}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00038500000000000003, 'epoch': 0.235}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00038250000000000003, 'epoch': 0.24}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00038, 'epoch': 0.245}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003775, 'epoch': 0.25}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000375, 'epoch': 0.255}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003725, 'epoch': 0.26}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00037, 'epoch': 0.265}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003675, 'epoch': 0.27}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000365, 'epoch': 0.275}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003625, 'epoch': 0.28}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00035999999999999997, 'epoch': 0.285}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003575, 'epoch': 0.29}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000355, 'epoch': 0.295}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003525, 'epoch': 0.3}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00035, 'epoch': 0.305}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003475, 'epoch': 0.31}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000345, 'epoch': 0.315}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00034250000000000003, 'epoch': 0.32}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00034, 'epoch': 0.325}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003375, 'epoch': 0.33}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000335, 'epoch': 0.335}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003325, 'epoch': 0.34}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00033, 'epoch': 0.345}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00032750000000000005, 'epoch': 0.35}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00032500000000000004, 'epoch': 0.355}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00032250000000000003, 'epoch': 0.36}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00032, 'epoch': 0.365}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003175, 'epoch': 0.37}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000315, 'epoch': 0.375}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003125, 'epoch': 0.38}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00031, 'epoch': 0.385}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003075, 'epoch': 0.39}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000305, 'epoch': 0.395}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003025, 'epoch': 0.4}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0003, 'epoch': 0.405}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00029749999999999997, 'epoch': 0.41}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000295, 'epoch': 0.415}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002925, 'epoch': 0.42}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00029, 'epoch': 0.425}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002875, 'epoch': 0.43}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000285, 'epoch': 0.435}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002825, 'epoch': 0.44}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00028000000000000003, 'epoch': 0.445}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002775, 'epoch': 0.45}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000275, 'epoch': 0.455}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002725, 'epoch': 0.46}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00027, 'epoch': 0.465}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002675, 'epoch': 0.47}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00026500000000000004, 'epoch': 0.475}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00026250000000000004, 'epoch': 0.48}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00026000000000000003, 'epoch': 0.485}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002575, 'epoch': 0.49}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000255, 'epoch': 0.495}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002525, 'epoch': 0.5}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00025, 'epoch': 0.505}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002475, 'epoch': 0.51}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000245, 'epoch': 0.515}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00024249999999999999, 'epoch': 0.52}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00024, 'epoch': 0.525}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002375, 'epoch': 0.53}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000235, 'epoch': 0.535}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002325, 'epoch': 0.54}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00023, 'epoch': 0.545}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002275, 'epoch': 0.55}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00022500000000000002, 'epoch': 0.555}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00022250000000000001, 'epoch': 0.56}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00022, 'epoch': 0.565}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002175, 'epoch': 0.57}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000215, 'epoch': 0.575}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002125, 'epoch': 0.58}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00021, 'epoch': 0.585}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002075, 'epoch': 0.59}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000205, 'epoch': 0.595}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00020250000000000002, 'epoch': 0.6}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0002, 'epoch': 0.605}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001975, 'epoch': 0.61}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00019500000000000002, 'epoch': 0.615}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00019250000000000002, 'epoch': 0.62}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00019, 'epoch': 0.625}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001875, 'epoch': 0.63}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000185, 'epoch': 0.635}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001825, 'epoch': 0.64}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00017999999999999998, 'epoch': 0.645}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001775, 'epoch': 0.65}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000175, 'epoch': 0.655}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001725, 'epoch': 0.66}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00017, 'epoch': 0.665}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001675, 'epoch': 0.67}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000165, 'epoch': 0.675}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00016250000000000002, 'epoch': 0.68}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00016, 'epoch': 0.685}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001575, 'epoch': 0.69}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000155, 'epoch': 0.695}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001525, 'epoch': 0.7}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00015, 'epoch': 0.705}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001475, 'epoch': 0.71}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000145, 'epoch': 0.715}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001425, 'epoch': 0.72}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00014000000000000001, 'epoch': 0.725}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001375, 'epoch': 0.73}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000135, 'epoch': 0.735}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00013250000000000002, 'epoch': 0.74}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00013000000000000002, 'epoch': 0.745}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001275, 'epoch': 0.75}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000125, 'epoch': 0.755}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001225, 'epoch': 0.76}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00012, 'epoch': 0.765}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001175, 'epoch': 0.77}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000115, 'epoch': 0.775}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00011250000000000001, 'epoch': 0.78}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.00011, 'epoch': 0.785}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001075, 'epoch': 0.79}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.000105, 'epoch': 0.795}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001025, 'epoch': 0.8}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 0.0001, 'epoch': 0.805}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 9.750000000000001e-05, 'epoch': 0.81}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 9.5e-05, 'epoch': 0.815}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 9.25e-05, 'epoch': 0.82}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 8.999999999999999e-05, 'epoch': 0.825}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 8.75e-05, 'epoch': 0.83}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 8.5e-05, 'epoch': 0.835}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 8.25e-05, 'epoch': 0.84}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 8e-05, 'epoch': 0.845}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 7.75e-05, 'epoch': 0.85}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 7.5e-05, 'epoch': 0.855}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 7.25e-05, 'epoch': 0.86}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 7.000000000000001e-05, 'epoch': 0.865}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 6.75e-05, 'epoch': 0.87}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 6.500000000000001e-05, 'epoch': 0.875}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 6.25e-05, 'epoch': 0.88}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 6e-05, 'epoch': 0.885}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 5.75e-05, 'epoch': 0.89}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 5.5e-05, 'epoch': 0.895}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 5.25e-05, 'epoch': 0.9}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 5e-05, 'epoch': 0.905}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 4.75e-05, 'epoch': 0.91}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 4.4999999999999996e-05, 'epoch': 0.915}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 4.25e-05, 'epoch': 0.92}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 4e-05, 'epoch': 0.925}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 3.75e-05, 'epoch': 0.93}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 3.5000000000000004e-05, 'epoch': 0.935}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 3.2500000000000004e-05, 'epoch': 0.94}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 3e-05, 'epoch': 0.945}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 2.75e-05, 'epoch': 0.95}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 2.5e-05, 'epoch': 0.955}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 2.2499999999999998e-05, 'epoch': 0.96}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 2e-05, 'epoch': 0.965}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 1.7500000000000002e-05, 'epoch': 0.97}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 1.5e-05, 'epoch': 0.975}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 1.25e-05, 'epoch': 0.98}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 1e-05, 'epoch': 0.985}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 7.5e-06, 'epoch': 0.99}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 5e-06, 'epoch': 0.995}
# {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 2.5e-06, 'epoch': 1.0}
# {'train_runtime': 20.5952, 'train_samples_per_second': 9.711, 'train_steps_per_second': 9.711, 'train_loss': 165.28835376739502, 'epoch': 1.0}
# TrainOutput(global_step=200, training_loss=165.28835376739502, metrics={'train_runtime': 20.5952, 'train_samples_per_second': 9.711, 'train_steps_per_second': 9.711, 'train_loss': 165.28835376739502, 'epoch': 1.0})

# %%
def summarize(article):
    prompt = (
        "### Instruction:\n"
        "Summarize the following article in one concise sentence.\n\n"
        "### Article:\n"
        f"{article}\n\n"
        "### Summary:\n"
    )

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    output = model.generate(
        **inputs,
        max_new_tokens=40,
        temperature=0.7,
        top_p=0.9,
        do_sample=True,
        eos_token_id=tokenizer.eos_token_id
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
trainer.save_model("./final-phi2-xsum")
tokenizer.save_pretrained("./final-phi2-xsum")
# Out:
# ('./final-phi2-xsum/tokenizer_config.json',
#  './final-phi2-xsum/special_tokens_map.json',
#  './final-phi2-xsum/vocab.json',
#  './final-phi2-xsum/merges.txt',
#  './final-phi2-xsum/added_tokens.json',
#  './final-phi2-xsum/tokenizer.json')
